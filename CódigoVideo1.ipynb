# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarstivenmoreno2008-coder/Porgramacion/blob/main/C%C3%B3digoVideo1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Oscar Stiven Moreno Guerrero-
# codigos video 1

# %% [markdown]
# Listas

# %%
lista = [10, True, 5.89, "hola"]

lista[2] = "buenos días"

print(lista)
# Out:
# [10, True, 'buenos días', 'hola']

# %%
lista = [10, True, 5.89, "hola"]

print(lista[1:3])
# Out:
# [True, 5.89]

# %%
lista_nueva = [1, 2, 3, 4]

lista_nueva.append(3)

print(lista_nueva)

print(lista_nueva.count(3))

print(lista_nueva.index(4))

lista_nueva.remove(3)

print(lista_nueva)
# Out:
# [1, 2, 3, 4, 3]
# 2
# 3
# [1, 2, 4, 3]

# %% [markdown]
# Tuplas

# %%
tupla = ("¿cómo estás?", True, False)

print((1,))
# Out:
# (1,)

# %% [markdown]
# Conjuntos

# %%
print(set([1, 5, 8, 2]))
print(set((1, 5, 8, 2)))
print(set("4356.8"))
# Out:
# {8, 1, 2, 5}
# {8, 1, 2, 5}
# {'6', '8', '3', '4', '.', '5'}

# %%
conjunto = set([7, 2, 3, 4])
print(conjunto)

conjunto.add(1)
print(conjunto)

conjunto.remove(1)
print(conjunto)
# Out:
# {2, 3, 4, 7}
# {1, 2, 3, 4, 7}
# {2, 3, 4, 7}

# %%
conjunto_2 = set([1, 5, 3, 6])
conjunto_3 = set([6, 3])
print(conjunto, conjunto_2, conjunto_3)
print(conjunto.intersection(conjunto_2))
print(conjunto & conjunto_2)
# Out:
# {2, 3, 4, 7} {1, 3, 5, 6} {3, 6}
# {3}
# {3}

# %% [markdown]
# Diccionarios

# %%
diccionario = {1: "uno", 2: "dos"}
diccionario[3] = "tres"
print(diccionario)

dict_lista_tuplas = dict([(1, "uno"), (2, "dos"), (3,"tres")])
print(dict_lista_tuplas)

dict_lista_string = dict(uno = 1, dos = 2, tres = 3)
print(dict_lista_string)

dict_tipos = {1: "integer", 2.2: "float", "texto": "string", (1, 2): "tupla"}
print(dict_tipos)

dict_repeticion = {1:"primero", 1: "ultimo"}
print(dict_repeticion)

print(diccionario, diccionario.keys(), diccionario.values(), diccionario.items())
claves = diccionario.values()
print(claves)
diccionario[1] = "one"
print(claves)
diccionario.pop(2)
print(diccionario)
# Out:
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {1: 'uno', 2: 'dos', 3: 'tres'}
# {'uno': 1, 'dos': 2, 'tres': 3}
# {1: 'integer', 2.2: 'float', 'texto': 'string', (1, 2): 'tupla'}
# {1: 'ultimo'}
# {1: 'uno', 2: 'dos', 3: 'tres'} dict_keys([1, 2, 3]) dict_values(['uno', 'dos', 'tres']) dict_items([(1, 'uno'), (2, 'dos'), (3, 'tres')])
# dict_values(['uno', 'dos', 'tres'])
# dict_values(['one', 'dos', 'tres'])
# {1: 'one', 3: 'tres'}
