# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarstivenmoreno2008-coder/Porgramacion/blob/main/Parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nombre: Oscar Stiven Moreno Guerrero
#
# Parte II
#
# Instrución 1:

# %%
A = { 1, 2, 3}
B = { 1, 5, 6}

# %%
A.difference (B)
# Out:
# {2, 3}

# %% [markdown]
# La sentencia difference me da los valores de A que son diferentes de los valores de B que sería el conjunto resultante {2, 3}

# %%
A = { 1, 2, 3}
B = { 1, 5, 6}

# %%
A.symmetric_difference (B)
# Out:
# {2, 3, 5, 6}

# %% [markdown]
# La sentencia symmetric_difference me da un conjunto con los valores del conjunto A y el conjunto B que no son comunes entre ellos. Es decir, me da los valores que no comparten entre sí.

# %% [markdown]
# Instrución 2:

# %%
A = {1, 2, 3, 4, 5, 6}
B = {1, 2, 3}

# %%
A.issuperset(B)
# Out:
# True

# %% [markdown]
# La sentencia verificó que fuera cierto(true) o falso(false) que los elementos de B estén contenidos en A. En este caso es verdadero y se podría deducir que el conjunto de valores serían {1, 2, 3, 4, 5, 6}

# %%
A.isdisjoint(B)
# Out:
# False

# %% [markdown]
# La sentencia verifica que el conjunto A este contenido en B lo cuál es falso. Y daría el conjunto {1, 2, 3}

# %% [markdown]
# Instrución 3:

# %%
datos2 = {"edad":19, "peso":90}

# %%
datos2.update({"semestre":2, "edad":19, "programación":1, "peso":85})
datos2
# Out:
# {'edad': 19, 'peso': 85, 'semestre': 2, 'programación': 1}

# %% [markdown]
# Este método une las clave:valor, de los dos diccionarios en uno solo.
# Si agrego una clave:valor repetida no la imprime en el diccionario que me está dando. Y si modifico el valor de una clave existente me da la clave con el valor actualizado.

# %% [markdown]
# Instrución 4:

# %%
datos3 = {"FcBarcelona":1, "champions":5}

# %%
datos3.setdefault("jugador", 10)
datos3
# Out:
# {'FcBarcelona': 1, 'champions': 5, 'jugador': 10}

# %% [markdown]
# Este metodo me permite agregar una nueva clave:valor a mi diccionario.

# %%
datos3.setdefault("FcBarcelona", 10)
datos3
# Out:
# {'FcBarcelona': 1, 'champions': 5, 'jugador': 10}

# %% [markdown]
# Si anoto una clave que ya existe en mi diccionario pero con un valor diferente me deuelve la misma clave:valor inicial sin modificarla.

# %%
datos3.setdefault("FcBarcelona", 1)
datos3
# Out:
# {'FcBarcelona': 1, 'champions': 5, 'jugador': 10}

# %% [markdown]
# si anoto una clave:valor repetida no la imprime y deja el diccionario igual.

# %% [markdown]
# Parte III
# Código 1:

# %%
m = 5
if isinstance(m, int) and m >= 0:
  for n in range(0, (m+1)):
    if n == 6 or n == -3:
      print("El número es ", n)
    else:
      for x in range(2, n):
        if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
      else: # Este else corresponde al for, no al if
       print(n, 'es un número primo')
else:
  print("El número no es natural")
# Out:
# 0 es un número primo
# 1 es un número primo
# 2 es un número primo
# 3 es un número primo
# 4 es igual a 2 * 2
# 5 es un número primo

# %%
m = "a"
if isinstance(m, int) and m >= 0:
  for n in range(0, (m+1)):
    if n == 1 or n == 0:
      print("El número es ", n)
    else:
      for x in range(2, n):
        if n % x == 0:
          print(n, 'es igual a', x, '*', n // x)
          break
      else: # Este else corresponde al for, no al if
       print(n, 'es un número primo')
else:
  print("El número no es natural")
# Out:
# El número no es natural

# %% [markdown]
# Código 2:

# %%
def contador_vocales1(PRogramacIoN):
  vocales = "aeiou"
  consonantes = "bcdfghjklmnñpqrstvwxyz"
  contador = 0
  contador1 = 0
  contador2 = 0

  for letra in palabra.lower():
    if letra in vocales:
      contador += 1
    elif letra in consonantes:
      contador1 += 1
    else:
      contador2 += 1
  return({"Cantidad de vocales:": contador,
          "Cantidad de consonates:": contador1,
          "Cantidad de otros caracteres:": contador2})
