# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarstivenmoreno2008-coder/Porgramacion/blob/main/tarea%203%20grupo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
z1 = 3+2j
z2 = 2+5j
print(type(z1))
print(z1)
print(type(z2))
print(z2)
# Out:
# <class 'complex'>
# (3+2j)
# <class 'complex'>
# (2+5j)

# %%
def suma(z1, z2):
    resultado = z1 + z2
    return resultado

# %%
suma = z1 + z2
print(suma)
# Out:
# (5+7j)

# %%
def multiplicacion(z1, z2):
    resultado = z1 * z2
    return resultado

# %%
multiplicaciòn = z1 * z2
print(multiplicaciòn)
# Out:
# (-4+19j)

# %%
def raiz_n(z, n):
    resultado = z ** (1/n)
    return resultado

# %%
raiz_complejos = raiz_n(z1, z2)
print(raiz_complejos)
# Out:
# (1.1893835808220288-0.21712518261118496j)

# %%
 def pedir_complejo():
     print("Ingrese la parte real:")
     real = leer()
     print("Ingrese la parte imaginaria:")
     imag = leer()
     z = complex(real, imag)
     return z
