# %% [markdown]
# <a href="https://colab.research.google.com/github/oscarstivenmoreno2008-coder/Porgramacion/blob/main/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()
    password = input("Contraseña: ")

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    if usuarios[usuario] != password:
        raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: ANA
# Contraseña: 1234
# Bienvenido, ANA

# %%
usuarios = {
    "ANA": "1234",
    "JUAN": "abcd"
}

try:
    usuario = input("Usuario: ").upper()

    if usuario not in usuarios:
        raise KeyError("El usuario no existe")

    elif usuarios[usuario] != input("Contraseña: "):
      raise ValueError("Contraseña incorrecta")

    else:
        print("Bienvenido,", usuario)

except KeyError as e:
    print("Error:", e)

except ValueError as e:
    print("Error:", e)
# Out:
# Usuario: JUAN
# Contraseña: abcd
# Bienvenido, JUAN

# %%
try:
  num1 = float(input("Número 1: "))
  num2 = float(input("Número 2: "))
  op = input("Operación (+, -, *, /): ")

  if op == "+":
    resultado = num1 + num2
  elif op == "-":
    resultado = num1 - num2
  elif op == "*":
    resultado = num1 * num2
  elif op == "/":
    resultado = num1 / num2
  else:
    raise ValueError("Operación no válida")

  print("Resultado:", resultado)

except ValueError as e:
    print("Error:", e)

except ZeroDivisionError as e:
    print("No se puede dividir entre cero")

except TypeError as e:
    print("Error de tipo:", e)
# Out:
# Número 1: 1
# Número 2: 2
# Operación (+, -, *, /): +
# Resultado: 3.0

# %%
try:
  num1 = float(input("Número 1: "))
  num2 = float(input("Número 2: "))
  op = input("Operación (+, -, *, /): ")

  if op == "+":
    resultado = num1 + num2
  elif op == "-":
    resultado = num1 - num2
  elif op == "*":
    resultado = num1 * num2
  elif op == "/":
    resultado = num1 / num2
  else:
    raise ValueError("Operación no válida")

  print("Resultado:", resultado)

except ValueError as e:
    # Check if the ValueError is due to float conversion or invalid operation
    if "could not convert string to float" in str(e) or "invalid literal for float" in str(e):
        print("Error: Por favor, introduce solo números para los operandos.")
    else:
        print("Error:", e) # This handles "Operación no válida"
except ZeroDivisionError:
    print("Error: No se puede dividir entre cero.")
# Out:
# Número 1: a
# Error: could not convert string to float: 'a'

# %%
try:
  num1 = (input("Número 1: "))
  num2 = (input("Número 2: "))
  op = input("Operación (+, -, *, /): ")

  if op == "+":
    resultado = num1 + num2
  elif op == "-":
    resultado = num1 - num2
  elif op == "*":
    resultado = num1 * num2
  elif op == "/":
    resultado = num1 / num2
  else:
    raise ValueError("Operación no válida")

  print("Resultado:", resultado)

except ValueError as e:
    print("Error:", e)

except ZeroDivisionError as e:
    print("No se puede dividir entre cero")

except TypeError as e:
    print("Error de tipo:", e)
# Out:
# Número 1: 5
# Número 2: 0
# Operación (+, -, *, /): /
# Error de tipo: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# se da el error porque python no puede dividir entre dos cadenas ya que no se puede dividir entre textos y me da typeerror

# %%
try:
datos = input("Ingresa números separados por coma: ")
lista = [int(x) for x in datos.split(",")]

indice = int(input("Índice a consultar: "))
    print("Elemento:", lista[indice])

except ValueError:
    print("Debes ingresar solo números")

except IndexError:
# Out:
#   File "/tmp/ipykernel_574/3375016649.py", line 2
#     datos = input("Ingresa números separados por coma: ")
#     ^
# IndentationError: expected an indented block after 'try' statement on line 1
